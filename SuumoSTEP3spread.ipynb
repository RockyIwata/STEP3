# %% [markdown]
# <a href="https://colab.research.google.com/github/RockyIwata/STEP3/blob/main/SuumoSTEP3spread.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials
import json
import pandas as pd

# %%
SP_CREDENTIAL_FILE = '/content/gspread-test-step3-267b4903a38a.json'
SP_COPE = [
    'https://www.googleapis.com/auth/drive',
    'https://spreadsheets.google.com/feeds'
]
SP_SHEET_KEY = '18ajvVjBf3SW3DvPZWACtXRc-Adi87ObV6TXSULhK4f8'
SP_SHEET = 'demo'

# %%
credentials = ServiceAccountCredentials.from_json_keyfile_name(SP_CREDENTIAL_FILE, SP_COPE)
gc = gspread.authorize(credentials)

# %%
sh = gc.open_by_key(SP_SHEET_KEY)

# %%
worksheet = sh.worksheet(SP_SHEET)

# %%
data = worksheet.get_all_values()
data
# Out:
# [['物件名',
#   '住所',
#   '築年数',
#   '階',
#   '家賃[万円]',
#   '管理費[万円]',
#   '敷金[万円]',
#   '礼金[万円]',
#   '間取り',
#   '専有面積[m2]'],
#  ['kif', '東京都新宿区若宮町', '15', '3', '25', '0.7', '50', '0', '3K', '51.79'],
#  ['アヴァンティーク銀座２丁目参番館',
#   '東京都中央区銀座２',
#   '19',
#   '9',
#   '20',
#   '1',
#   '20',
#   '20',
#   '2DK',
#   '42.84'],
#  ['銀座レジデンス伍番館',
#   '東京都中央区湊２',
#   '20',
#   '2',
#   '19.2',
#   '0',
#   '19.2',
#   '19.2',
#   '2DK',
#   '50.38'],
#  ['銀座レジデンス伍番館',
#   '東京都中央区湊２',
#   '20',
#   '4',
#   '19.5',
#   '0',
#   '19.5',
#   '19.5',
#   '2DK',
#   '50.38'],
#  ['銀座レジデンス伍番館', '東京都中央区湊２', '20', '11', '21', '0', '21', '21', '2DK', '52.21'],
#  ['kinomori代々木上原', '東京都渋谷区上原２', '1', '4', '12.7', '1', '0', '0', '2K', '23.7'],
#  ['kinomori代々木上原',
#   '東京都渋谷区上原２',
#   '1',
#   '2',
#   '13.1',
#   '1',
#   '0',
#   '0',
#   '2K',
#   '24.08'],
#  ['kinomori代々木上原',
#   '東京都渋谷区上原２',
#   '1',
#   '3',
#   '13.2',
#   '1',
#   '0',
#   '0',
#   '2K',
#   '24.08'],
# ...

# %%
df = pd.DataFrame(data[1:], columns=data[0])
df
# Out:
#                              物件名          住所 築年数     階 家賃[万円] 管理費[万円] 敷金[万円]  \
# 0                            kif   東京都新宿区若宮町  15     3     25     0.7     50
# 1               アヴァンティーク銀座２丁目参番館   東京都中央区銀座２  19     9     20       1     20
# 2                     銀座レジデンス伍番館    東京都中央区湊２  20     2   19.2       0   19.2
# 3                     銀座レジデンス伍番館    東京都中央区湊２  20     4   19.5       0   19.5
# 4                     銀座レジデンス伍番館    東京都中央区湊２  20    11     21       0     21
# ..                           ...         ...  ..   ...    ...     ...    ...
# 599                     ラブランシュール    東京都港区白金６   5     1   22.9       1   22.9
# 600  東京メトロ南北線 白金高輪駅 地下1地上4階建 築5年    東京都港区白金６   5  B1-1   22.9       1   22.9
# 601                   プラチナコート南麻布   東京都港区南麻布１  19     3   24.1       1      0
# 602         都営大江戸線 若松河田駅 6階建 築9年   東京都新宿区河田町   9     5     23       1     23
# 603                   ＤｅＬＣＣＳ市谷柳町  東京都新宿区市谷柳町   3     9   24.7       1      0
#
#     礼金[万円]   間取り 専有面積[m2]
# ...

# %% [markdown]
# # 新しいセクション
